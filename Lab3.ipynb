# %% [markdown]
# <a href="https://colab.research.google.com/github/konarksharma2001/pthon/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Handling Missing Data
#
# ```
# # This is formatted as code
# ```

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('melbourne.csv')

# %%
df.head()
# Out:
#        Suburb             Address  ...             Regionname Propertycount
# 0  Abbotsford       68 Studley St  ...  Northern Metropolitan        4019.0
# 1  Abbotsford        85 Turner St  ...  Northern Metropolitan        4019.0
# 2  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan        4019.0
# 3  Abbotsford  18/659 Victoria St  ...  Northern Metropolitan        4019.0
# 4  Abbotsford        5 Charles St  ...  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23547 non-null  object
#  1   Address        23547 non-null  object
#  2   Rooms          23547 non-null  int64
#  3   Type           23547 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         23547 non-null  object
#  6   SellerG        23547 non-null  object
#  7   Date           23547 non-null  object
#  8   Distance       23546 non-null  float64
#  9   Postcode       23546 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  BuildingArea   10018 non-null  float64
#  15  YearBuilt      11540 non-null  float64
#  16  CouncilArea    15656 non-null  object
#  17  Lattitude      19243 non-null  float64
#  18  Longtitude     19243 non-null  float64
#  19  Regionname     23546 non-null  object
#  20  Propertycount  23546 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 3.8+ MB

# %%
df.isnull()
# Out:
#        Suburb  Address  Rooms  ...  Longtitude  Regionname  Propertycount
# 0       False    False  False  ...       False       False          False
# 1       False    False  False  ...       False       False          False
# 2       False    False  False  ...       False       False          False
# 3       False    False  False  ...       False       False          False
# 4       False    False  False  ...       False       False          False
# ...       ...      ...    ...  ...         ...         ...            ...
# 23542   False    False  False  ...       False       False          False
# 23543   False    False  False  ...       False       False          False
# 23544   False    False  False  ...       False       False          False
# 23545   False    False  False  ...       False       False          False
# 23546   False    False  False  ...       False       False          False
#
# [23547 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
# columns having at least one missing value
df.isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %%
# above is equivalent to axis=0 (by default, any() operates on columns)
df.isnull().any(axis=0)
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 23542     True
# 23543     True
# 23544     True
# 23545     True
# 23546     True
# Length: 23547, dtype: bool

# %%
# rows having all missing values
df.isnull().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23542    False
# 23543    False
# 23544    False
# 23545    False
# 23546    False
# Length: 23547, dtype: bool

# %%
# sum it up to check how many rows have all missing values
df.isnull().all(axis=1).sum()
# Out:
# 0

# %%
# sum of misisng values in each row
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
#         ..
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %% [markdown]
# #Treating Missing Values in Columns

# %%
# summing up the missing values (column-wise)
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
# removing the three columns
df = df.drop('BuildingArea', axis=1)
df = df.drop('YearBuilt', axis=1)
df = df.drop('CouncilArea', axis=1)

round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %% [markdown]
# #Treating Missing Values in Rows

# %%
df[df.isnull().sum(axis=1) > 5]
# Out:
#                   Suburb  ... Propertycount
# 15            Abbotsford  ...        4019.0
# 16            Abbotsford  ...        4019.0
# 19            Abbotsford  ...        4019.0
# 21            Abbotsford  ...        4019.0
# 22            Abbotsford  ...        4019.0
# ...                  ...  ...           ...
# 23495  Templestowe Lower  ...        5420.0
# 23499          Thornbury  ...        8870.0
# 23502          Thornbury  ...        8870.0
# 23508             Toorak  ...        7217.0
# 23531           Werribee  ...       16166.0
#
# [4278 rows x 18 columns]

# %%
# count the number of rows having > 5 missing values
# use len(df.index)
len(df[df.isnull().sum(axis=1) > 5].index)
# Out:
# 4278

# %%
100*(len(df[df.isnull().sum(axis=1) > 5].index) / len(df.index))
# Out:
# 18.16791948018856

# %%
# retaining the rows having <= 5 NaNs
df = df[df.isnull().sum(axis=1) <= 5]

# look at the summary again
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
# removing NaN Price rows
df = df[~np.isnan(df['Price'])]

round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         1.05
# Bathroom         1.07
# Car              1.76
# Landsize         9.83
# Lattitude        0.15
# Longtitude       0.15
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df['Landsize'].describe()
# Out:
# count     13603.000000
# mean        558.116371
# std        3987.326586
# min           0.000000
# 25%         176.500000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
# removing NaNs in Landsize
df = df[~np.isnan(df['Landsize'])]

round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
# rows having Lattitude and Longitude missing
df[np.isnan(df['Lattitude'])]
# Out:
#                    Suburb  ... Propertycount
# 2572              Burwood  ...        5678.0
# 3257         Clifton Hill  ...        2954.0
# 4485            Footscray  ...        7570.0
# 5170         Hampton East  ...        2356.0
# 10745  Williamstown North  ...         802.0
# 13223           Melbourne  ...       17496.0
# 14008            Brooklyn  ...         962.0
# 14132     North Melbourne  ...        6821.0
# 14139      Oakleigh South  ...        3692.0
# 14142      Oakleigh South  ...        3692.0
# 14143      Oakleigh South  ...        3692.0
# 14976            Essendon  ...        9264.0
# 15278              Seddon  ...        2417.0
# 15561             Croydon  ...       11925.0
# 16358          Kensington  ...        5263.0
# 16564          Strathmore  ...        3284.0
# 17616          Kensington  ...        5263.0
# 17620         Keysborough  ...        8459.0
# 18141               Lalor  ...        8279.0
# 18614           Mickleham  ...        1158.0
# 18793             Wollert  ...        2940.0
# 18995           Greenvale  ...        4864.0
#
# [22 rows x 18 columns]

# %%
df.loc[:, ['Lattitude', 'Longtitude']].describe()
# Out:
#           Lattitude    Longtitude
# count  13581.000000  13581.000000
# mean     -37.809204    144.995221
# std        0.079257      0.103913
# min      -38.182550    144.431810
# 25%      -37.856820    144.929600
# 50%      -37.802360    145.000100
# 75%      -37.756400    145.058320
# max      -37.408530    145.526350

# %%
# imputing Lattitude and Longitude by mean values
df.loc[np.isnan(df['Lattitude']), ['Lattitude']] = df['Lattitude'].mean()
df.loc[np.isnan(df['Longtitude']), ['Longtitude']] = df['Longtitude'].mean()

round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df.loc[:, ['Bathroom', 'Car']].describe()
# Out:
#            Bathroom           Car
# count  13602.000000  13540.000000
# mean       1.534921      1.610414
# std        0.691834      0.962244
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        1.000000      2.000000
# 75%        2.000000      2.000000
# max        8.000000     10.000000

# %%
# converting to type 'category'
df['Car'] = df['Car'].astype('category')

# displaying frequencies of each category
df['Car'].value_counts()
# Out:
# 2.0     5606
# 1.0     5515
# 0.0     1026
# 3.0      748
# 4.0      507
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: Car, dtype: int64

# %%
# imputing NaNs by 2.0
df.loc[pd.isnull(df['Car']), ['Car']] = 2
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.00
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
# converting to type 'category'
df['Bathroom'] = df['Bathroom'].astype('category')

# displaying frequencies of each category
df['Bathroom'].value_counts()
# Out:
# 1.0    7517
# 2.0    4987
# 3.0     921
# 4.0     106
# 0.0      34
# 5.0      28
# 6.0       5
# 8.0       2
# 7.0       2
# Name: Bathroom, dtype: int64

# %%
# imputing NaNs by 1
df.loc[pd.isnull(df['Bathroom']), ['Bathroom']] = 1
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Price            0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# dtype: float64

# %%
df.shape
# Out:
# (13603, 18)

# %%
# fraction of rows lost
len(df.index)/23547
# Out:
# 0.5776956724848176
